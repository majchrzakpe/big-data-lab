# %%
REPO_NAME="big-data-lab"
USER_NAME="majchrzakpe" # TODO: replace with your GitHub username

# %%
# %env REPO_NAME=$REPO_NAME
# %env USER_NAME=$USER_NAME
# Out:
# env: REPO_NAME=big-data-lab
# env: USER_NAME=Majki9601

# %%
# %%shell
# rm -rf $REPO_NAME
# git clone https://github.com/$USER_NAME/$REPO_NAME.git
# cd $REPO_NAME
# Out:
# Cloning into 'big-data-lab'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 111 (delta 28), reused 13 (delta 13), pack-reused 68 (from 2)
# Receiving objects: 100% (111/111), 448.45 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# %run $REPO_NAME/notebooks/lib/00_terraform_setup.ipynb
# Out:
# env: TERRAFORM_VERSION=1.9.8
# env: PATH=/content/bin:/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# --2024-12-21 13:32:25--  https://releases.hashicorp.com/terraform/1.9.8/terraform_1.9.8_linux_amd64.zip
# Resolving releases.hashicorp.com (releases.hashicorp.com)... 18.238.217.13, 18.238.217.30, 18.238.217.70, ...
# Connecting to releases.hashicorp.com (releases.hashicorp.com)|18.238.217.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27041434 (26M) [application/zip]
# Saving to: ‘terraform_1.9.8_linux_amd64.zip’
#
# terraform_1.9.8_lin 100%[===================>]  25.79M  --.-KB/s    in 0.1s
#
# 2024-12-21 13:32:25 (196 MB/s) - ‘terraform_1.9.8_linux_amd64.zip’ saved [27041434/27041434]
#
# Archive:  terraform_1.9.8_linux_amd64.zip
#   inflating: bin/LICENSE.txt
#   inflating: bin/terraform
# Terraform v1.9.8
# on linux_amd64
#
# Your version of Terraform is out of date! The latest version
# is 1.10.2. You can update by downloading from https://www.terraform.io/downloads.html

# %%
# %run $REPO_NAME/notebooks/conf/00_env_variables.ipynb
# Out:
# env: TF_VAR_ds_semester=2024l
# env: TF_VAR_user_id=7026
# env: TF_VAR_billing_account=016BA9-8361D5-8FDBEA
# env: TF_VAR_region=europe-west1
# env: TF_VAR_project_name=ds-2024l-7026
# env: GIT_BRANCH=colab-dev

# %%
# Authenticate to the Google account
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# ### Set the remote bucket for storing Terraform state

# %%
import os
TF_VAR_user_id = os.getenv("TF_VAR_user_id")
TF_VAR_user_id
# Out:
# '7026'

# %%
import subprocess

command = f"cd {REPO_NAME}/infra && terraform init -backend-config=bucket=ds-2024l-{TF_VAR_user_id}-state"

result = subprocess.run(command, shell=True, check=True)
print("Komenda zakończona sukcesem", result)
# Out:
# Komenda zakończona sukcesem CompletedProcess(args='cd big-data-lab/infra && terraform init -backend-config=bucket=ds-2024l-7026-state', returncode=0)

# %% [markdown]
# ### Provision the infrastructure

# %%
# %%shell
# cd $REPO_NAME/infra
# terraform apply -auto-approve
# Out:
# Acquiring state lock. This may take a few moments...
#
# Terraform used the selected providers to generate the following execution plan. Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # module.dataproc.google_dataproc_cluster.dataproc-cluster will be created
#   + resource "google_dataproc_cluster" "dataproc-cluster" {
#       + effective_labels              = (known after apply)
#       + graceful_decommission_timeout = "0s"
#       + id                            = (known after apply)
#       + name                          = "ds-cluster"
#       + project                       = "ds-2024l-7026"
#       + region                        = "europe-west1"
#       + terraform_labels              = (known after apply)
#
#       + cluster_config {
#           + bucket      = (known after apply)
#           + temp_bucket = (known after apply)
#
#           + auxiliary_node_groups (known after apply)
#
#           + dataproc_metric_config (known after apply)
#
#           + endpoint_config {
#               + enable_http_port_access = true
#               + http_ports              = (known after apply)
#             }
#
#           + gce_cluster_config {
#               + internal_ip_only       = true
#               + metadata               = {
#                   + "PIP_PACKAGES" = "pandas<2 mlflow==2.18.0 google-cloud-storage==2.18.2"
#                   + "vmDnsSetting" = "GlobalDefault"
#                 }
#               + network                = (known after apply)
#               + service_account        = (known after apply)
#               + service_account_scopes = [
#                   + "https://www.googleapis.com/auth/cloud-platform",
#                 ]
#               + subnetwork             = (known after apply)
#               + zone                   = (known after apply)
#
#               + node_group_affinity (known after apply)
#
#               + reservation_affinity (known after apply)
#
#               + shielded_instance_config (known after apply)
#             }
#
#           + initialization_action {
#               + script      = "gs://goog-dataproc-initialization-actions-europe-west1/python/pip-install.sh"
#               + timeout_sec = 600
#             }
#
#           + lifecycle_config {
#               + idle_delete_ttl = "21600s"
#               + idle_start_time = (known after apply)
#             }
#
#           + master_config {
#               + image_uri        = (known after apply)
#               + instance_names   = (known after apply)
#               + machine_type     = "e2-standard-2"
#               + min_cpu_platform = (known after apply)
#               + num_instances    = 1
#
#               + disk_config {
#                   + boot_disk_size_gb = 100
#                   + boot_disk_type    = "pd-standard"
#                   + num_local_ssds    = (known after apply)
#                 }
#             }
#
#           + preemptible_worker_config (known after apply)
#
#           + software_config {
#               + image_version       = "2.2-ubuntu22"
#               + optional_components = [
#                   + "JUPYTER",
#                 ]
#               + override_properties = {
#                   + "dataproc:jupyter.notebook.gcs.dir" = "gs://ds-2024l-7026-notebook-data/data"
#                 }
#               + properties          = (known after apply)
#             }
#
#           + worker_config {
#               + image_uri         = (known after apply)
#               + instance_names    = (known after apply)
#               + machine_type      = "e2-standard-2"
#               + min_cpu_platform  = (known after apply)
#               + min_num_instances = (known after apply)
#               + num_instances     = 2
#
#               + disk_config {
#                   + boot_disk_size_gb = 100
#                   + boot_disk_type    = "pd-standard"
#                   + num_local_ssds    = (known after apply)
#                 }
#             }
#         }
#
#       + virtual_cluster_config (known after apply)
#     }
#
#   # module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"] will be created
#   + resource "google_project_iam_member" "dataproc-service-account" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "ds-2024l-7026"
#       + role    = "roles/dataproc.worker"
#     }
#
#   # module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"] will be created
#   + resource "google_project_iam_member" "dataproc-service-account" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "ds-2024l-7026"
#       + role    = "roles/storage.admin"
#     }
#
#   # module.dataproc.google_project_service.dataproc will be created
#   + resource "google_project_service" "dataproc" {
#       + disable_on_destroy = true
#       + id                 = (known after apply)
#       + project            = "ds-2024l-7026"
#       + service            = "dataproc.googleapis.com"
#     }
#
#   # module.dataproc.google_service_account.default will be created
#   + resource "google_service_account" "default" {
#       + account_id   = "ds-service-account"
#       + disabled     = false
#       + display_name = "DS Lab Service Account"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "ds-2024l-7026"
#       + unique_id    = (known after apply)
#     }
#
#   # module.vpc.google_compute_firewall.default-internal-allow-all will be created
#   + resource "google_compute_firewall" "default-internal-allow-all" {
#       + creation_timestamp = (known after apply)
#       + destination_ranges = (known after apply)
#       + direction          = "INGRESS"
#       + enable_logging     = (known after apply)
#       + id                 = (known after apply)
#       + name               = "default-internal-allow-all"
#       + network            = (known after apply)
#       + priority           = 65534
#       + project            = "ds-2024l-7026"
#       + self_link          = (known after apply)
#       + source_ranges      = [
#           + "10.10.10.0/24",
#         ]
#
#       + allow {
#           + ports    = []
#           + protocol = "all"
#         }
#     }
#
#   # module.vpc.google_compute_firewall.fw-allow-ingress-from-iap will be created
#   + resource "google_compute_firewall" "fw-allow-ingress-from-iap" {
#       + creation_timestamp = (known after apply)
#       + destination_ranges = (known after apply)
#       + direction          = "INGRESS"
#       + enable_logging     = (known after apply)
#       + id                 = (known after apply)
#       + name               = "fw-allow-ingress-iap"
#       + network            = (known after apply)
#       + priority           = 1000
#       + project            = "ds-2024l-7026"
#       + self_link          = (known after apply)
#       + source_ranges      = [
#           + "35.235.240.0/20",
#         ]
#
#       + allow {
#           + ports    = [
#               + "22",
#               + "8443",
#               + "443",
#               + "80",
#               + "8000",
#             ]
#           + protocol = "tcp"
#         }
#     }
#
#   # module.vpc.module.cloud-router.google_compute_router.router will be created
#   + resource "google_compute_router" "router" {
#       + creation_timestamp = (known after apply)
#       + id                 = (known after apply)
#       + name               = "nat-router"
#       + network            = (known after apply)
#       + project            = "ds-2024l-7026"
#       + region             = "europe-west1"
#       + self_link          = (known after apply)
#     }
#
#   # module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"] will be created
#   + resource "google_compute_router_nat" "nats" {
#       + auto_network_tier                   = (known after apply)
#       + drain_nat_ips                       = (known after apply)
#       + enable_dynamic_port_allocation      = (known after apply)
#       + enable_endpoint_independent_mapping = (known after apply)
#       + endpoint_types                      = (known after apply)
#       + icmp_idle_timeout_sec               = 30
#       + id                                  = (known after apply)
#       + min_ports_per_vm                    = (known after apply)
#       + name                                = "nat-gateway"
#       + nat_ip_allocate_option              = "AUTO_ONLY"
#       + nat_ips                             = (known after apply)
#       + project                             = "ds-2024l-7026"
#       + region                              = "europe-west1"
#       + router                              = "nat-router"
#       + source_subnetwork_ip_ranges_to_nat  = "ALL_SUBNETWORKS_ALL_IP_RANGES"
#       + tcp_established_idle_timeout_sec    = 1200
#       + tcp_time_wait_timeout_sec           = 120
#       + tcp_transitory_idle_timeout_sec     = 30
#       + udp_idle_timeout_sec                = 30
#
#       + log_config {
#           + enable = true
#           + filter = "ALL"
#         }
#     }
#
#   # module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"] will be created
#   + resource "google_compute_route" "route" {
#       + description            = "route through IGW to access internet"
#       + dest_range             = "0.0.0.0/0"
#       + id                     = (known after apply)
#       + name                   = "egress-internet"
#       + network                = "main-vpc"
#       + next_hop_gateway       = "default-internet-gateway"
#       + next_hop_instance_zone = (known after apply)
#       + next_hop_ip            = (known after apply)
#       + next_hop_network       = (known after apply)
#       + priority               = 1000
#       + project                = "ds-2024l-7026"
#       + self_link              = (known after apply)
#     }
#
#   # module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"] will be created
#   + resource "google_compute_subnetwork" "subnetwork" {
#       + creation_timestamp         = (known after apply)
#       + external_ipv6_prefix       = (known after apply)
#       + fingerprint                = (known after apply)
#       + gateway_address            = (known after apply)
#       + id                         = (known after apply)
#       + internal_ipv6_prefix       = (known after apply)
#       + ip_cidr_range              = "10.10.10.0/24"
#       + ipv6_cidr_range            = (known after apply)
#       + name                       = "dataproc-01"
#       + network                    = "main-vpc"
#       + private_ip_google_access   = true
#       + private_ipv6_google_access = (known after apply)
#       + project                    = "ds-2024l-7026"
#       + purpose                    = (known after apply)
#       + region                     = "europe-west1"
#       + self_link                  = (known after apply)
#       + stack_type                 = (known after apply)
#
#       + secondary_ip_range (known after apply)
#     }
#
#   # module.vpc.module.vpc.module.vpc.google_compute_network.network will be created
#   + resource "google_compute_network" "network" {
#       + auto_create_subnetworks                   = false
#       + delete_default_routes_on_create           = false
#       + enable_ula_internal_ipv6                  = false
#       + gateway_ipv4                              = (known after apply)
#       + id                                        = (known after apply)
#       + internal_ipv6_range                       = (known after apply)
#       + mtu                                       = 0
#       + name                                      = "main-vpc"
#       + network_firewall_policy_enforcement_order = "AFTER_CLASSIC_FIREWALL"
#       + numeric_id                                = (known after apply)
#       + project                                   = "ds-2024l-7026"
#       + routing_mode                              = "GLOBAL"
#       + self_link                                 = (known after apply)
#         # (1 unchanged attribute hidden)
#     }
#
# Plan: 12 to add, 0 to change, 0 to destroy.
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Creating...
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Still creating... [10s elapsed]
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Creation complete after 12s [id=projects/ds-2024l-7026/global/networks/main-vpc]
# module.vpc.module.cloud-router.google_compute_router.router: Creating...
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Creating...
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Creating...
# module.vpc.google_compute_firewall.default-internal-allow-all: Creating...
# module.vpc.module.cloud-router.google_compute_router.router: Still creating... [10s elapsed]
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Still creating... [10s elapsed]
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Still creating... [10s elapsed]
# module.vpc.google_compute_firewall.default-internal-allow-all: Still creating... [10s elapsed]
# module.vpc.google_compute_firewall.default-internal-allow-all: Creation complete after 11s [id=projects/ds-2024l-7026/global/firewalls/default-internal-allow-all]
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Creation complete after 11s [id=projects/ds-2024l-7026/global/firewalls/fw-allow-ingress-iap]
# module.vpc.module.cloud-router.google_compute_router.router: Creation complete after 17s [id=projects/ds-2024l-7026/regions/europe-west1/routers/nat-router]
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Creating...
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Still creating... [20s elapsed]
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Creation complete after 26s [id=projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Creating...
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Still creating... [10s elapsed]
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Creation complete after 12s [id=ds-2024l-7026/europe-west1/nat-router/nat-gateway]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Still creating... [10s elapsed]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Creation complete after 11s [id=projects/ds-2024l-7026/global/routes/egress-internet]
# module.dataproc.google_service_account.default: Creating...
# module.dataproc.google_project_service.dataproc: Creating...
# module.dataproc.google_service_account.default: Still creating... [10s elapsed]
# module.dataproc.google_project_service.dataproc: Still creating... [10s elapsed]
# module.dataproc.google_service_account.default: Creation complete after 11s [id=projects/ds-2024l-7026/serviceAccounts/ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"]: Creating...
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"]: Creating...
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"]: Creation complete after 7s [id=ds-2024l-7026/roles/dataproc.worker/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"]: Creation complete after 8s [id=ds-2024l-7026/roles/storage.admin/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_service.dataproc: Still creating... [20s elapsed]
# module.dataproc.google_project_service.dataproc: Creation complete after 21s [id=ds-2024l-7026/dataproc.googleapis.com]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Creating...
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... [10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... [20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... [30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... [40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... [50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still creating... 0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Creation complete after 7m1s [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster]
# Releasing state lock. This may take a few moments...
#
# Apply complete! Resources: 12 added, 0 changed, 0 destroyed.

# %% [markdown]
# ### Destroy the infrastructure
# After you are done with the lab, you can destroy the infrastructure by running the cell below:

# %%
# %%shell
# cd $REPO_NAME/infra
# terraform destroy -auto-approve
# Out:
# Acquiring state lock. This may take a few moments...
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Refreshing state... [id=projects/ds-2024l-7026/global/networks/main-vpc]
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Refreshing state... [id=projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01]
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Refreshing state... [id=projects/ds-2024l-7026/global/firewalls/fw-allow-ingress-iap]
# module.vpc.google_compute_firewall.default-internal-allow-all: Refreshing state... [id=projects/ds-2024l-7026/global/firewalls/default-internal-allow-all]
# module.vpc.module.cloud-router.google_compute_router.router: Refreshing state... [id=projects/ds-2024l-7026/regions/europe-west1/routers/nat-router]
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Refreshing state... [id=ds-2024l-7026/europe-west1/nat-router/nat-gateway]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Refreshing state... [id=projects/ds-2024l-7026/global/routes/egress-internet]
# module.dataproc.google_project_service.dataproc: Refreshing state... [id=ds-2024l-7026/dataproc.googleapis.com]
# module.dataproc.google_service_account.default: Refreshing state... [id=projects/ds-2024l-7026/serviceAccounts/ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"]: Refreshing state... [id=ds-2024l-7026/roles/storage.admin/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"]: Refreshing state... [id=ds-2024l-7026/roles/dataproc.worker/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Refreshing state... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster]
#
# Terraform used the selected providers to generate the following execution plan. Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # module.dataproc.google_dataproc_cluster.dataproc-cluster will be destroyed
#   - resource "google_dataproc_cluster" "dataproc-cluster" {
#       - effective_labels              = {
#           - "goog-dataproc-autozone"     = "enabled"
#           - "goog-dataproc-cluster-name" = "ds-cluster"
#           - "goog-dataproc-cluster-uuid" = "010ed2de-fd29-4a51-92ef-cb1065aa9d0a"
#           - "goog-dataproc-location"     = "europe-west1"
#         } -> null
#       - graceful_decommission_timeout = "0s" -> null
#       - id                            = "projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster" -> null
#       - labels                        = {} -> null
#       - name                          = "ds-cluster" -> null
#       - project                       = "ds-2024l-7026" -> null
#       - region                        = "europe-west1" -> null
#       - terraform_labels              = {} -> null
#
#       - cluster_config {
#           - bucket         = "dataproc-staging-europe-west1-611921846271-3mwkyrxl" -> null
#           - temp_bucket    = "dataproc-temp-europe-west1-611921846271-waix1tw1" -> null
#             # (1 unchanged attribute hidden)
#
#           - endpoint_config {
#               - enable_http_port_access = true -> null
#               - http_ports              = {
#                   - "HDFS NameNode"             = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/hdfs/dfshealth.html"
#                   - "Jupyter"                   = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/gateway/default/jupyter/"
#                   - "JupyterLab"                = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/gateway/default/jupyter/lab/"
#                   - "MapReduce Job History"     = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/jobhistory/"
#                   - "Spark History Server"      = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/sparkhistory/"
#                   - "Tez"                       = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/apphistory/tez-ui/"
#                   - "YARN Application Timeline" = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/apphistory/"
#                   - "YARN ResourceManager"      = "https://4baslkrbovchxcrtbbxcxk4mx4-dot-europe-west1.dataproc.googleusercontent.com/yarn/"
#                 } -> null
#             }
#
#           - gce_cluster_config {
#               - internal_ip_only       = true -> null
#               - metadata               = {
#                   - "PIP_PACKAGES" = "pandas<2 mlflow==2.18.0 google-cloud-storage==2.18.2"
#                   - "vmDnsSetting" = "GlobalDefault"
#                 } -> null
#               - service_account        = "ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#               - service_account_scopes = [
#                   - "https://www.googleapis.com/auth/cloud-platform",
#                   - "https://www.googleapis.com/auth/cloud.useraccounts.readonly",
#                   - "https://www.googleapis.com/auth/devstorage.read_write",
#                   - "https://www.googleapis.com/auth/logging.write",
#                 ] -> null
#               - subnetwork             = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01" -> null
#               - tags                   = [] -> null
#               - zone                   = "europe-west1-d" -> null
#                 # (1 unchanged attribute hidden)
#
#               - shielded_instance_config {
#                   - enable_integrity_monitoring = true -> null
#                   - enable_secure_boot          = true -> null
#                   - enable_vtpm                 = true -> null
#                 }
#             }
#
#           - initialization_action {
#               - script      = "gs://goog-dataproc-initialization-actions-europe-west1/python/pip-install.sh" -> null
#               - timeout_sec = 600 -> null
#             }
#
#           - lifecycle_config {
#               - idle_delete_ttl  = "21600s" -> null
#                 # (2 unchanged attributes hidden)
#             }
#
#           - master_config {
#               - image_uri        = "https://www.googleapis.com/compute/v1/projects/cloud-dataproc/global/images/dataproc-2-2-ubu22-20241026-165100-rc02" -> null
#               - instance_names   = [
#                   - "ds-cluster-m",
#                 ] -> null
#               - machine_type     = "e2-standard-2" -> null
#               - min_cpu_platform = "AUTOMATIC" -> null
#               - num_instances    = 1 -> null
#
#               - disk_config {
#                   - boot_disk_size_gb   = 100 -> null
#                   - boot_disk_type      = "pd-standard" -> null
#                   - num_local_ssds      = 0 -> null
#                     # (1 unchanged attribute hidden)
#                 }
#             }
#
#           - preemptible_worker_config {
#               - instance_names = [] -> null
#               - num_instances  = 0 -> null
#                 # (1 unchanged attribute hidden)
#
#               - disk_config {}
#
#               - instance_flexibility_policy {
#                   - instance_selection_results = [] -> null
#                 }
#             }
#
#           - software_config {
#               - image_version       = "2.2.40-ubuntu22" -> null
#               - optional_components = [
#                   - "JUPYTER",
#                 ] -> null
#               - override_properties = {
#                   - "dataproc:jupyter.notebook.gcs.dir" = "gs://ds-2024l-7026-notebook-data/data"
#                 } -> null
#               - properties          = {
#                   - "capacity-scheduler:yarn.scheduler.capacity.resource-calculator"                          = "org.apache.hadoop.yarn.util.resource.DominantResourceCalculator"
#                   - "capacity-scheduler:yarn.scheduler.capacity.root.default.ordering-policy"                 = "fair"
#                   - "core:fs.gs.block.size"                                                                   = "134217728"
#                   - "core:fs.gs.metadata.cache.enable"                                                        = "false"
#                   - "core:hadoop.ssl.enabled.protocols"                                                       = "TLSv1,TLSv1.1,TLSv1.2"
#                   - "dataproc:jupyter.notebook.gcs.dir"                                                       = "gs://ds-2024l-7026-notebook-data/data"
#                   - "distcp:mapreduce.map.java.opts"                                                          = "-Xmx576m"
#                   - "distcp:mapreduce.map.memory.mb"                                                          = "768"
#                   - "distcp:mapreduce.reduce.java.opts"                                                       = "-Xmx576m"
#                   - "distcp:mapreduce.reduce.memory.mb"                                                       = "768"
#                   - "hadoop-env:HADOOP_DATANODE_OPTS"                                                         = "-Xmx512m"
#                   - "hdfs:dfs.datanode.address"                                                               = "0.0.0.0:9866"
#                   - "hdfs:dfs.datanode.http.address"                                                          = "0.0.0.0:9864"
#                   - "hdfs:dfs.datanode.https.address"                                                         = "0.0.0.0:9865"
#                   - "hdfs:dfs.datanode.ipc.address"                                                           = "0.0.0.0:9867"
#                   - "hdfs:dfs.namenode.handler.count"                                                         = "20"
#                   - "hdfs:dfs.namenode.http-address"                                                          = "0.0.0.0:9870"
#                   - "hdfs:dfs.namenode.https-address"                                                         = "0.0.0.0:9871"
#                   - "hdfs:dfs.namenode.lifeline.rpc-address"                                                  = "ds-cluster-m:8050"
#                   - "hdfs:dfs.namenode.secondary.http-address"                                                = "0.0.0.0:9868"
#                   - "hdfs:dfs.namenode.secondary.https-address"                                               = "0.0.0.0:9869"
#                   - "hdfs:dfs.namenode.service.handler.count"                                                 = "10"
#                   - "hdfs:dfs.namenode.servicerpc-address"                                                    = "ds-cluster-m:8051"
#                   - "mapred-env:HADOOP_JOB_HISTORYSERVER_HEAPSIZE"                                            = "2048"
#                   - "mapred:mapreduce.job.maps"                                                               = "9"
#                   - "mapred:mapreduce.job.reduce.slowstart.completedmaps"                                     = "0.95"
#                   - "mapred:mapreduce.job.reduces"                                                            = "3"
#                   - "mapred:mapreduce.jobhistory.recovery.store.class"                                        = "org.apache.hadoop.mapreduce.v2.hs.HistoryServerLeveldbStateStoreService"
#                   - "mapred:mapreduce.map.cpu.vcores"                                                         = "1"
#                   - "mapred:mapreduce.map.java.opts"                                                          = "-Xmx2621m"
#                   - "mapred:mapreduce.map.memory.mb"                                                          = "3277"
#                   - "mapred:mapreduce.reduce.cpu.vcores"                                                      = "1"
#                   - "mapred:mapreduce.reduce.java.opts"                                                       = "-Xmx2621m"
#                   - "mapred:mapreduce.reduce.memory.mb"                                                       = "3277"
#                   - "mapred:mapreduce.task.io.sort.mb"                                                        = "256"
#                   - "mapred:yarn.app.mapreduce.am.command-opts"                                               = "-Xmx2621m"
#                   - "mapred:yarn.app.mapreduce.am.resource.cpu-vcores"                                        = "1"
#                   - "mapred:yarn.app.mapreduce.am.resource.mb"                                                = "3277"
#                   - "spark-env:SPARK_DAEMON_MEMORY"                                                           = "2048m"
#                   - "spark:spark.driver.maxResultSize"                                                        = "1024m"
#                   - "spark:spark.driver.memory"                                                               = "2048m"
#                   - "spark:spark.executor.cores"                                                              = "1"
#                   - "spark:spark.executor.instances"                                                          = "2"
#                   - "spark:spark.executor.memory"                                                             = "2893m"
#                   - "spark:spark.executorEnv.OPENBLAS_NUM_THREADS"                                            = "1"
#                   - "spark:spark.plugins.defaultList"                                                         = "com.google.cloud.dataproc.DataprocSparkPlugin"
#                   - "spark:spark.scheduler.mode"                                                              = "FAIR"
#                   - "spark:spark.sql.cbo.enabled"                                                             = "true"
#                   - "spark:spark.sql.optimizer.runtime.bloomFilter.join.pattern.enabled"                      = "true"
#                   - "spark:spark.ui.port"                                                                     = "0"
#                   - "spark:spark.yarn.am.memory"                                                              = "640m"
#                   - "yarn-env:YARN_NODEMANAGER_HEAPSIZE"                                                      = "819"
#                   - "yarn-env:YARN_RESOURCEMANAGER_HEAPSIZE"                                                  = "2048"
#                   - "yarn-env:YARN_TIMELINESERVER_HEAPSIZE"                                                   = "2048"
#                   - "yarn:yarn.nodemanager.address"                                                           = "0.0.0.0:8026"
#                   - "yarn:yarn.nodemanager.resource.cpu-vcores"                                               = "2"
#                   - "yarn:yarn.nodemanager.resource.memory-mb"                                                = "6554"
#                   - "yarn:yarn.resourcemanager.decommissioning-nodes-watcher.decommission-if-no-shuffle-data" = "true"
#                   - "yarn:yarn.resourcemanager.nodemanager-graceful-decommission-timeout-secs"                = "86400"
#                   - "yarn:yarn.scheduler.maximum-allocation-mb"                                               = "6554"
#                   - "yarn:yarn.scheduler.minimum-allocation-mb"                                               = "1"
#                 } -> null
#             }
#
#           - worker_config {
#               - image_uri         = "https://www.googleapis.com/compute/v1/projects/cloud-dataproc/global/images/dataproc-2-2-ubu22-20241026-165100-rc02" -> null
#               - instance_names    = [
#                   - "ds-cluster-w-0",
#                   - "ds-cluster-w-1",
#                 ] -> null
#               - machine_type      = "e2-standard-2" -> null
#               - min_cpu_platform  = "AUTOMATIC" -> null
#               - min_num_instances = 0 -> null
#               - num_instances     = 2 -> null
#
#               - disk_config {
#                   - boot_disk_size_gb   = 100 -> null
#                   - boot_disk_type      = "pd-standard" -> null
#                   - num_local_ssds      = 0 -> null
#                     # (1 unchanged attribute hidden)
#                 }
#             }
#         }
#     }
#
#   # module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"] will be destroyed
#   - resource "google_project_iam_member" "dataproc-service-account" {
#       - etag    = "BwYpx9Yb5CU=" -> null
#       - id      = "ds-2024l-7026/roles/dataproc.worker/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - member  = "serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - project = "ds-2024l-7026" -> null
#       - role    = "roles/dataproc.worker" -> null
#     }
#
#   # module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"] will be destroyed
#   - resource "google_project_iam_member" "dataproc-service-account" {
#       - etag    = "BwYpx9Yb5CU=" -> null
#       - id      = "ds-2024l-7026/roles/storage.admin/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - member  = "serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - project = "ds-2024l-7026" -> null
#       - role    = "roles/storage.admin" -> null
#     }
#
#   # module.dataproc.google_project_service.dataproc will be destroyed
#   - resource "google_project_service" "dataproc" {
#       - disable_on_destroy = true -> null
#       - id                 = "ds-2024l-7026/dataproc.googleapis.com" -> null
#       - project            = "ds-2024l-7026" -> null
#       - service            = "dataproc.googleapis.com" -> null
#     }
#
#   # module.dataproc.google_service_account.default will be destroyed
#   - resource "google_service_account" "default" {
#       - account_id   = "ds-service-account" -> null
#       - disabled     = false -> null
#       - display_name = "DS Lab Service Account" -> null
#       - email        = "ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - id           = "projects/ds-2024l-7026/serviceAccounts/ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - member       = "serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - name         = "projects/ds-2024l-7026/serviceAccounts/ds-service-account@ds-2024l-7026.iam.gserviceaccount.com" -> null
#       - project      = "ds-2024l-7026" -> null
#       - unique_id    = "103312453094412618700" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # module.vpc.google_compute_firewall.default-internal-allow-all will be destroyed
#   - resource "google_compute_firewall" "default-internal-allow-all" {
#       - creation_timestamp      = "2024-12-21T05:34:33.999-08:00" -> null
#       - destination_ranges      = [] -> null
#       - direction               = "INGRESS" -> null
#       - disabled                = false -> null
#       - id                      = "projects/ds-2024l-7026/global/firewalls/default-internal-allow-all" -> null
#       - name                    = "default-internal-allow-all" -> null
#       - network                 = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/networks/main-vpc" -> null
#       - priority                = 65534 -> null
#       - project                 = "ds-2024l-7026" -> null
#       - self_link               = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/firewalls/default-internal-allow-all" -> null
#       - source_ranges           = [
#           - "10.10.10.0/24",
#         ] -> null
#       - source_service_accounts = [] -> null
#       - source_tags             = [] -> null
#       - target_service_accounts = [] -> null
#       - target_tags             = [] -> null
#         # (1 unchanged attribute hidden)
#
#       - allow {
#           - ports    = [] -> null
#           - protocol = "all" -> null
#         }
#     }
#
#   # module.vpc.google_compute_firewall.fw-allow-ingress-from-iap will be destroyed
#   - resource "google_compute_firewall" "fw-allow-ingress-from-iap" {
#       - creation_timestamp      = "2024-12-21T05:34:34.016-08:00" -> null
#       - destination_ranges      = [] -> null
#       - direction               = "INGRESS" -> null
#       - disabled                = false -> null
#       - id                      = "projects/ds-2024l-7026/global/firewalls/fw-allow-ingress-iap" -> null
#       - name                    = "fw-allow-ingress-iap" -> null
#       - network                 = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/networks/main-vpc" -> null
#       - priority                = 1000 -> null
#       - project                 = "ds-2024l-7026" -> null
#       - self_link               = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/firewalls/fw-allow-ingress-iap" -> null
#       - source_ranges           = [
#           - "35.235.240.0/20",
#         ] -> null
#       - source_service_accounts = [] -> null
#       - source_tags             = [] -> null
#       - target_service_accounts = [] -> null
#       - target_tags             = [] -> null
#         # (1 unchanged attribute hidden)
#
#       - allow {
#           - ports    = [
#               - "22",
#               - "8443",
#               - "443",
#               - "80",
#               - "8000",
#             ] -> null
#           - protocol = "tcp" -> null
#         }
#     }
#
#   # module.vpc.module.cloud-router.google_compute_router.router will be destroyed
#   - resource "google_compute_router" "router" {
#       - creation_timestamp            = "2024-12-21T05:34:38.245-08:00" -> null
#       - encrypted_interconnect_router = false -> null
#       - id                            = "projects/ds-2024l-7026/regions/europe-west1/routers/nat-router" -> null
#       - name                          = "nat-router" -> null
#       - network                       = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/networks/main-vpc" -> null
#       - project                       = "ds-2024l-7026" -> null
#       - region                        = "europe-west1" -> null
#       - self_link                     = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/regions/europe-west1/routers/nat-router" -> null
#         # (1 unchanged attribute hidden)
#     }
#
#   # module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"] will be destroyed
#   - resource "google_compute_router_nat" "nats" {
#       - auto_network_tier                   = "PREMIUM" -> null
#       - drain_nat_ips                       = [] -> null
#       - enable_dynamic_port_allocation      = false -> null
#       - enable_endpoint_independent_mapping = false -> null
#       - endpoint_types                      = [
#           - "ENDPOINT_TYPE_VM",
#         ] -> null
#       - icmp_idle_timeout_sec               = 30 -> null
#       - id                                  = "ds-2024l-7026/europe-west1/nat-router/nat-gateway" -> null
#       - max_ports_per_vm                    = 0 -> null
#       - min_ports_per_vm                    = 0 -> null
#       - name                                = "nat-gateway" -> null
#       - nat_ip_allocate_option              = "AUTO_ONLY" -> null
#       - nat_ips                             = [] -> null
#       - project                             = "ds-2024l-7026" -> null
#       - region                              = "europe-west1" -> null
#       - router                              = "nat-router" -> null
#       - source_subnetwork_ip_ranges_to_nat  = "ALL_SUBNETWORKS_ALL_IP_RANGES" -> null
#       - tcp_established_idle_timeout_sec    = 1200 -> null
#       - tcp_time_wait_timeout_sec           = 120 -> null
#       - tcp_transitory_idle_timeout_sec     = 30 -> null
#       - udp_idle_timeout_sec                = 30 -> null
#
#       - log_config {
#           - enable = true -> null
#           - filter = "ALL" -> null
#         }
#     }
#
#   # module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"] will be destroyed
#   - resource "google_compute_route" "route" {
#       - description         = "route through IGW to access internet" -> null
#       - dest_range          = "0.0.0.0/0" -> null
#       - id                  = "projects/ds-2024l-7026/global/routes/egress-internet" -> null
#       - name                = "egress-internet" -> null
#       - network             = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/networks/main-vpc" -> null
#       - next_hop_gateway    = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/gateways/default-internet-gateway" -> null
#       - priority            = 1000 -> null
#       - project             = "ds-2024l-7026" -> null
#       - self_link           = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/routes/egress-internet" -> null
#       - tags                = [] -> null
#         # (5 unchanged attributes hidden)
#     }
#
#   # module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"] will be destroyed
#   - resource "google_compute_subnetwork" "subnetwork" {
#       - creation_timestamp         = "2024-12-21T05:34:36.374-08:00" -> null
#       - gateway_address            = "10.10.10.1" -> null
#       - id                         = "projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01" -> null
#       - ip_cidr_range              = "10.10.10.0/24" -> null
#       - name                       = "dataproc-01" -> null
#       - network                    = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/networks/main-vpc" -> null
#       - private_ip_google_access   = true -> null
#       - private_ipv6_google_access = "DISABLE_GOOGLE_ACCESS" -> null
#       - project                    = "ds-2024l-7026" -> null
#       - purpose                    = "PRIVATE" -> null
#       - region                     = "europe-west1" -> null
#       - self_link                  = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01" -> null
#       - stack_type                 = "IPV4_ONLY" -> null
#         # (7 unchanged attributes hidden)
#     }
#
#   # module.vpc.module.vpc.module.vpc.google_compute_network.network will be destroyed
#   - resource "google_compute_network" "network" {
#       - auto_create_subnetworks                   = false -> null
#       - delete_default_routes_on_create           = false -> null
#       - enable_ula_internal_ipv6                  = false -> null
#       - id                                        = "projects/ds-2024l-7026/global/networks/main-vpc" -> null
#       - mtu                                       = 0 -> null
#       - name                                      = "main-vpc" -> null
#       - network_firewall_policy_enforcement_order = "AFTER_CLASSIC_FIREWALL" -> null
#       - numeric_id                                = "5540951725596966193" -> null
#       - project                                   = "ds-2024l-7026" -> null
#       - routing_mode                              = "GLOBAL" -> null
#       - self_link                                 = "https://www.googleapis.com/compute/v1/projects/ds-2024l-7026/global/networks/main-vpc" -> null
#         # (3 unchanged attributes hidden)
#     }
#
# Plan: 0 to add, 0 to change, 12 to destroy.
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 40s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 50s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 1m0s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 1m10s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 1m20s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/clusters/ds-cluster, 1m30s elapsed]
# module.dataproc.google_dataproc_cluster.dataproc-cluster: Destruction complete after 1m32s
# module.dataproc.google_project_service.dataproc: Destroying... [id=ds-2024l-7026/dataproc.googleapis.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"]: Destroying... [id=ds-2024l-7026/roles/storage.admin/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"]: Destroying... [id=ds-2024l-7026/roles/dataproc.worker/serviceAccount:ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/storage.admin"]: Destruction complete after 8s
# module.dataproc.google_project_iam_member.dataproc-service-account["roles/dataproc.worker"]: Destruction complete after 8s
# module.dataproc.google_service_account.default: Destroying... [id=projects/ds-2024l-7026/serviceAccounts/ds-service-account@ds-2024l-7026.iam.gserviceaccount.com]
# module.dataproc.google_service_account.default: Destruction complete after 0s
# module.dataproc.google_project_service.dataproc: Still destroying... [id=ds-2024l-7026/dataproc.googleapis.com, 10s elapsed]
# module.dataproc.google_project_service.dataproc: Destruction complete after 11s
# module.vpc.google_compute_firewall.default-internal-allow-all: Destroying... [id=projects/ds-2024l-7026/global/firewalls/default-internal-allow-all]
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Destroying... [id=projects/ds-2024l-7026/global/firewalls/fw-allow-ingress-iap]
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Destroying... [id=ds-2024l-7026/europe-west1/nat-router/nat-gateway]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Destroying... [id=projects/ds-2024l-7026/global/routes/egress-internet]
# module.vpc.google_compute_firewall.default-internal-allow-all: Still destroying... [id=projects/ds-2024l-7026/global/firewalls/default-internal-allow-all, 10s elapsed]
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Still destroying... [id=projects/ds-2024l-7026/global/firewalls/fw-allow-ingress-iap, 10s elapsed]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Still destroying... [id=projects/ds-2024l-7026/global/routes/egress-internet, 10s elapsed]
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Still destroying... [id=ds-2024l-7026/europe-west1/nat-router/nat-gateway, 10s elapsed]
# module.vpc.module.vpc.module.routes.google_compute_route.route["egress-internet"]: Destruction complete after 11s
# module.vpc.google_compute_firewall.fw-allow-ingress-from-iap: Destruction complete after 12s
# module.vpc.google_compute_firewall.default-internal-allow-all: Destruction complete after 12s
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Destroying... [id=projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01]
# module.vpc.module.cloud-router.google_compute_router_nat.nats["nat-gateway"]: Destruction complete after 12s
# module.vpc.module.cloud-router.google_compute_router.router: Destroying... [id=projects/ds-2024l-7026/regions/europe-west1/routers/nat-router]
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01, 10s elapsed]
# module.vpc.module.cloud-router.google_compute_router.router: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/routers/nat-router, 10s elapsed]
# module.vpc.module.cloud-router.google_compute_router.router: Destruction complete after 11s
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Still destroying... [id=projects/ds-2024l-7026/regions/europe-west1/subnetworks/dataproc-01, 20s elapsed]
# module.vpc.module.vpc.module.subnets.google_compute_subnetwork.subnetwork["europe-west1/dataproc-01"]: Destruction complete after 22s
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Destroying... [id=projects/ds-2024l-7026/global/networks/main-vpc]
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Still destroying... [id=projects/ds-2024l-7026/global/networks/main-vpc, 10s elapsed]
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Still destroying... [id=projects/ds-2024l-7026/global/networks/main-vpc, 20s elapsed]
# module.vpc.module.vpc.module.vpc.google_compute_network.network: Destruction complete after 21s
# Releasing state lock. This may take a few moments...
#
# Destroy complete! Resources: 12 destroyed.
